# %% [markdown]
# ![earthkit-data-logo](https://github.com/ecmwf/logos/raw/refs/heads/main/logos/earthkit/earthkit-data-light.svg)

# %% [markdown]
# # Setup

# %% [markdown]
# The code below enables the caching of the data downloaded from remote sources in earthkit-data. By default the [cache policy](https://earthkit-data.readthedocs.io/en/latest/concepts/caching.html#cache-policies) is "off", so please run this cell to ensure that the [cache](https://earthkit-data.readthedocs.io/en/latest/concepts/caching.html) is enabled for the exercises using earthkit-data.

# %%
import earthkit.data as ekd

ekd.config.set("cache-policy", "user")

# %%
# print the config
ekd.config
