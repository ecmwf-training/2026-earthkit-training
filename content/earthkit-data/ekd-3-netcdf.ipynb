# %% [markdown]
# ## earthkit-data: NetCDF

# %%
import earthkit.data as ekd

# %%
d = ekd.from_source("sample", "era5_tquv_pl_subarea.nc")
d
# Out:
# <p><b>NetCDF file</b></br><b>Path</b>: /var/folders/93/w0p869rx17q98wxk83gn9ys40000gn/T/earthkit-data-cgr/url-3984fcbba44da17cbab035194fdce7b72c5ef001d293e8ff0504cbd5d2cb8d01.nc <b>size</b>: 14.6 MiB</br><b>Available types</b>: xarray, pandas, fieldlist, numpy, array</p>

# %%
d.available_types
# Out:
# ['xarray', 'pandas', 'fieldlist', 'numpy', 'array']

# %% [markdown]
# ### Conversion to Xarray

# %%
d.to_xarray()
# Out:
# <xarray.Dataset> Size: 35MB
# Dimensions:         (valid_time: 4, pressure_level: 3, latitude: 301,
#                      longitude: 601)
# Coordinates:
#   * valid_time      (valid_time) datetime64[ns] 32B 2016-09-26 ... 2016-09-26...
#   * pressure_level  (pressure_level) float64 24B 925.0 850.0 700.0
#   * latitude        (latitude) float64 2kB 90.0 89.75 89.5 ... 15.5 15.25 15.0
#   * longitude       (longitude) float64 5kB -100.0 -99.75 -99.5 ... 49.75 50.0
#     number          int64 8B ...
#     expver          (valid_time) <U4 64B dask.array<chunksize=(4,), meta=np.ndarray>
# Data variables:
#     q               (valid_time, pressure_level, latitude, longitude) float32 9MB dask.array<chunksize=(4, 3, 301, 601), meta=np.ndarray>
#     t               (valid_time, pressure_level, latitude, longitude) float32 9MB dask.array<chunksize=(4, 3, 301, 601), meta=np.ndarray>
#     u               (valid_time, pressure_level, latitude, longitude) float32 9MB dask.array<chunksize=(4, 3, 301, 601), meta=np.ndarray>
#     v               (valid_time, pressure_level, latitude, longitude) float32 9MB dask.array<chunksize=(4, 3, 301, 601), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-03-12T10:30 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# ### Conversion to fieldlist

# %%
fl = d.to_fieldlist()
len(fl)
# Out:
# Coordinate expver not supported
# axis='', name='expver', long_name='', standard_name='', units
#
# <xarray.DataArray 'expver' (valid_time: 4)> Size: 64B
# [4 values with dtype=<U4]
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 32B 2016-09-26 ... 2016-09-26T18:...
#     number      int64 8B ...
#     expver      (valid_time) <U4 64B ...
#
# <class 'numpy.ndarray'> (4,)
# 48

# %%
fl.head()
# Out:
#   parameter.variable time.valid_datetime  time.base_datetime time.step  \
# 0                  q 2016-09-26 00:00:00 2016-09-26 00:00:00    0 days
# 1                  q 2016-09-26 00:00:00 2016-09-26 00:00:00    0 days
# 2                  q 2016-09-26 00:00:00 2016-09-26 00:00:00    0 days
# 3                  q 2016-09-26 06:00:00 2016-09-26 06:00:00    0 days
# 4                  q 2016-09-26 06:00:00 2016-09-26 06:00:00    0 days
#
#    vertical.level vertical.level_type ensemble.member geography.grid_type
# 0           925.0            pressure               0                None
# 1           850.0            pressure               0                None
# 2           700.0            pressure               0                None
# 3           925.0            pressure               0                None
# 4           850.0            pressure               0                None

# %%
f = fl[0]
f
# Out:
# Field(q, 2016-09-26 00:00:00, 2016-09-26 00:00:00, 0:00:00, 925.0, pressure, 0, None)
